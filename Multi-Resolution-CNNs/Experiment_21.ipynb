# %%
# change the seed before anything else
import numpy as np
np.random.seed(7)
import tensorflow as tf
tf.set_random_seed(7)
from timeit import default_timer as timer

import os
import time

import keras
keras.backend.clear_session()

import matplotlib.pyplot as plt
import sklearn

import keras
from keras.preprocessing.image import ImageDataGenerator
from MixupGenerator import MixupGenerator
from keras.models import Sequential, Input, Model
from keras.layers import Activation
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Activation, 
merge, Flatten
from keras.layers.pooling import GlobalAveragePooling2D
from keras.layers.merge import concatenate
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# Using TensorFlow backend.

# %%
bands = 60
frames = 101
feature_size = bands * frames
num_channels = 3
num_labels = 10
data_dir = 'folds_da'

# %%
def load_all_folds(test_fold):
    assert (type(test_fold) == int)
    assert (test_fold > 0 and test_fold < 11)
    subsequent_fold = False

    train_set_range = list(range(1, 11))
    train_set_range.remove(test_fold)
    valid_fold = train_set_range.pop()

    for k in train_set_range:
        fold_name = 'fold' + str(k)
        feature_file = os.path.join(data_dir, fold_name + '_x.npy')
        labels_file = os.path.join(data_dir, fold_name + '_y.npy')
        loaded_features = np.load(feature_file)
        # flip the spectrogram for each channel
        loaded_features = np.transpose(loaded_features, (0, 2, 1, 3))
        loaded_labels = np.load(labels_file)
        print("Adding ", fold_name, "New Features: ", loaded_features.shape)

        if subsequent_fold:
            train_x_loaded = np.concatenate((train_x_loaded, loaded_features))
            train_y_loaded = np.concatenate((train_y_loaded, loaded_labels))
        else:
            train_x_loaded = loaded_features
            train_y_loaded = loaded_labels
            subsequent_fold = True

    # use the penultimate fold for validation
    valid_fold_name = 'fold' + str(valid_fold)
    feature_file = os.path.join(data_dir, valid_fold_name + '_x.npy')
    labels_file = os.path.join(data_dir, valid_fold_name + '_y.npy')
    valid_x = np.load(feature_file)
    # flip the spectrogram for each channel
    valid_x = np.transpose(valid_x, (0, 2, 1, 3))
    valid_y = np.load(labels_file)

    # and use the last fold for testing
    test_fold_name = 'fold' + str(test_fold)
    feature_file = os.path.join(data_dir, test_fold_name + '_x.npy')
    labels_file = os.path.join(data_dir, test_fold_name + '_y.npy')
    test_x = np.load(feature_file)
    test_x = np.transpose(test_x, (0, 2, 1, 3))
    test_y = np.load(labels_file)
    return train_x_loaded, train_y_loaded, valid_x, valid_y, test_x, test_y

# %%
def evaluate(model, test_x, test_y):
    y_prob = model.predict(test_x, verbose=0)
    y_pred = np.argmax(y_prob, axis=-1)
    y_true = np.argmax(test_y, 1)

    # evaluate the model
    score, accuracy = model.evaluate(test_x, test_y, batch_size=32)
    print("\nAccuracy = {:.4f}".format(accuracy))
    print("\nError Rate = {:.4f}".format(1. - accuracy))

    return accuracy

# %%
def build_model():
    # create model
    
    visible = Input(shape=(frames, bands, num_channels))
    
    # short frequency features
    # first filter
    conv1 = Conv2D(1, kernel_size=(4, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool1 = MaxPooling2D(pool_size=(1, 2))(conv1)
    dropout1 = Dropout(0.5)(conv1)
    flat1 = Flatten()(pool1)
    # second filter
    conv2 =Conv2D(1, kernel_size=(8, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool2 = MaxPooling2D(pool_size=(1, 2))(conv2)
    dropout2 = Dropout(0.5)(conv2)
    flat2 = Flatten()(pool2)
    # third filter
    conv3 =Conv2D(1, kernel_size=(12, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool3 = MaxPooling2D(pool_size=(1, 2))(conv3)
    dropout3 = Dropout(0.5)(conv3)
    flat3 = Flatten()(pool3)
    # fourth filter
    conv4 =Conv2D(1, kernel_size=(16, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool4 = MaxPooling2D(pool_size=(1, 2))(conv4)
    dropout4 = Dropout(0.5)(conv4)
    flat4 = Flatten()(pool4)
    # fifth filter
    conv5 =Conv2D(1, kernel_size=(20, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool5 = MaxPooling2D(pool_size=(1, 2))(conv5)
    dropout5 = Dropout(0.5)(conv5)
    flat5 = Flatten()(pool5)
    
    #medium frequency features
    # sixth filter
    conv6 = Conv2D(1, kernel_size=(24, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool6 = MaxPooling2D(pool_size=(1, 2))(conv6)
    dropout6 = Dropout(0.5)(conv6)
    flat6 = Flatten()(pool6)
    # seventh filter
    conv7 = Conv2D(1, kernel_size=(28, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool7 = MaxPooling2D(pool_size=(1, 2))(conv7)
    dropout7 = Dropout(0.5)(conv7)
    flat7 = Flatten()(pool7)
    # eighth filter
    conv8 = Conv2D(1, kernel_size=(32, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool8 = MaxPooling2D(pool_size=(1, 2))(conv8)
    dropout8 = Dropout(0.5)(conv8)
    flat8 = Flatten()(pool8)
    # ninth filter
    conv9 = Conv2D(1, kernel_size=(36, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool9 = MaxPooling2D(pool_size=(1, 2))(conv9)
    dropout9 = Dropout(0.5)(conv9)
    flat9 = Flatten()(pool9)
    # tenth filter
    conv10 = Conv2D(1, kernel_size=(40, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool10 = MaxPooling2D(pool_size=(1, 2))(conv10)
    dropout10 = Dropout(0.5)(conv10)
    flat10 = Flatten()(pool10)
    
    # long frequency feartures
    # eleventh filter
    conv11 = Conv2D(1, kernel_size=(44, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool11 = MaxPooling2D(pool_size=(1, 2))(conv11)
    dropout11 = Dropout(0.5)(conv11)
    flat11 = Flatten()(pool11)
    # twelth filter
    conv12 = Conv2D(1, kernel_size=(48, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool12 = MaxPooling2D(pool_size=(1, 2))(conv12)
    dropout12 = Dropout(0.5)(conv12)
    flat12 = Flatten()(pool12)
    # thirteenth filter
    conv13 = Conv2D(1, kernel_size=(52, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool13 = MaxPooling2D(pool_size=(1, 2))(conv13)
    dropout13 = Dropout(0.5)(conv13)
    flat13 = Flatten()(pool13)
    # fourteenth filter
    conv14 = Conv2D(1, kernel_size=(56, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool14 = MaxPooling2D(pool_size=(1, 2))(conv14)
    dropout14 = Dropout(0.5)(conv14)
    flat14 = Flatten()(pool14)
    # fifteenth filter
    conv15 = Conv2D(1, kernel_size=(60, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool15 = MaxPooling2D(pool_size=(1, 2))(conv15)
    dropout15 = Dropout(0.5)(conv15)
    flat15 = Flatten()(pool15)
    
    # short temporal features
    # 16
    conv16 = Conv2D(1, kernel_size=(4, 4), activation='relu', kernel_initializer='he_uniform')(visible)
    pool16 = MaxPooling2D(pool_size=(2, 1))(conv16)
    dropout16 = Dropout(0.5)(conv16)
    flat16 = Flatten()(pool16)
    # 17
    conv17 = Conv2D(1, kernel_size=(4, 8), activation='relu', kernel_initializer='he_uniform')(visible)
    pool17 = MaxPooling2D(pool_size=(2, 1))(conv17)
    dropout17 = Dropout(0.5)(conv17)
    flat17 = Flatten()(pool17)
    # 18
    conv18 = Conv2D(1, kernel_size=(4, 12), activation='relu', kernel_initializer='he_uniform')(visible)
    pool18 = MaxPooling2D(pool_size=(2, 1))(conv18)
    dropout18 = Dropout(0.5)(conv18)
    flat18 = Flatten()(pool18)
    # 19
    conv19 = Conv2D(1, kernel_size=(4, 16), activation='relu', kernel_initializer='he_uniform')(visible)
    pool19 = MaxPooling2D(pool_size=(2, 1))(conv19)
    dropout19 = Dropout(0.5)(conv19)
    flat19 = Flatten()(pool19)
    # 20
    conv20 = Conv2D(1, kernel_size=(4, 20), activation='relu', kernel_initializer='he_uniform')(visible)
    pool20 = MaxPooling2D(pool_size=(2, 1))(conv20)
    dropout20 = Dropout(0.5)(conv20)
    flat20 = Flatten()(pool20)

    #medium temporal filters
    # 21
    conv21 = Conv2D(1, kernel_size=(4, 24), activation='relu', kernel_initializer='he_uniform')(visible)
    pool21 = MaxPooling2D(pool_size=(2, 1))(conv21)
    dropout21 = Dropout(0.5)(conv21)
    flat21 = Flatten()(pool21)
    # 22
    conv22 = Conv2D(1, kernel_size=(4, 28), activation='relu', kernel_initializer='he_uniform')(visible)
    pool22 = MaxPooling2D(pool_size=(2, 1))(conv22)
    dropout22 = Dropout(0.5)(conv22)
    flat22 = Flatten()(pool22)
    # 23
    conv23 = Conv2D(1, kernel_size=(4, 32), activation='relu', kernel_initializer='he_uniform')(visible)
    pool23 = MaxPooling2D(pool_size=(2, 1))(conv23)
    dropout23 = Dropout(0.5)(conv23)
    flat23 = Flatten()(pool23)
    # 24
    conv24 = Conv2D(1, kernel_size=(4, 36), activation='relu', kernel_initializer='he_uniform')(visible)
    pool24 = MaxPooling2D(pool_size=(2, 1))(conv24)
    dropout24 = Dropout(0.5)(conv24)
    flat24 = Flatten()(pool24)
    # 25
    conv25 = Conv2D(1, kernel_size=(4, 40), activation='relu', kernel_initializer='he_uniform')(visible)
    pool25 = MaxPooling2D(pool_size=(2, 1))(conv25)
    dropout25 = Dropout(0.5)(conv25)
    flat25 = Flatten()(pool25)
    
    # long temporal features
    # 26
    conv26 = Conv2D(1, kernel_size=(4, 44), activation='relu', kernel_initializer='he_uniform')(visible)
    pool26 = MaxPooling2D(pool_size=(2, 1))(conv26)
    dropout26 = Dropout(0.5)(conv26)
    flat26 = Flatten()(pool26)
    # 27
    conv27 = Conv2D(1, kernel_size=(4, 48), activation='relu', kernel_initializer='he_uniform')(visible)
    pool27 = MaxPooling2D(pool_size=(2, 1))(conv27)
    dropout27 = Dropout(0.5)(conv27)
    flat27 = Flatten()(pool27)
    # 28
    conv28 = Conv2D(1, kernel_size=(4, 52), activation='relu', kernel_initializer='he_uniform')(visible)
    pool28 = MaxPooling2D(pool_size=(2, 1))(conv28)
    dropout28 = Dropout(0.5)(conv28)
    flat28 = Flatten()(pool28)
    # 29
    conv29 = Conv2D(1, kernel_size=(4, 56), activation='relu', kernel_initializer='he_uniform')(visible)
    pool29 = MaxPooling2D(pool_size=(2, 1))(conv29)
    dropout29 = Dropout(0.5)(conv29)
    flat29 = Flatten()(pool29)
    # 30
    conv30 = Conv2D(1, kernel_size=(4, 60), activation='relu', kernel_initializer='he_uniform')(visible)
    pool30 = MaxPooling2D(pool_size=(2, 1))(conv30)
    dropout30 = Dropout(0.5)(conv30)
    flat30 = Flatten()(pool30)
    
    # merge filters
    
    shortFT = concatenate([flat1, flat2, flat3, flat4, flat5,
                          flat16, flat17, flat18, flat19, flat20])
                           
    mediumFT = concatenate([flat6, flat7, flat8, flat9, flat10,
                          flat21, flat22, flat23, flat24, flat25])
                           
    longFT = concatenate([flat11, flat12, flat13, flat14, flat15,
                          flat26, flat27, flat28, flat29, flat30])
    
    merge = concatenate([shortFT, mediumFT, longFT])
    
    # interpretation layer
    hidden1 = Dense(5000, activation='relu')(merge)
    # prediction output
    output = Dense(10, activation='softmax')(hidden1)
    model = Model(inputs=visible, outputs=output)
    
    return model

# %%
# apply scaling factor to a dataset - train, validation or test
def do_scale(x4d, verbose = True):
    """Do scale on the input sequence data.

    Args:
      x34d: ndarray, input sequence data, shape: (n_clips, n_time, n_freq, channel)      
      verbose: boolean

    Returns:
      Scaled input sequence data.
    """
    t1 = time.time()    
    (n_clips, n_time, n_freq, n_channel) = x4d.shape
    x4d_scaled = np.zeros(x4d.shape)
    for channel in range(n_channel):
        x2d = x4d[:,:,:,channel].reshape((n_clips * n_time, n_freq))
        x2d_scaled = scaler_list[channel].transform(x2d)
        x3d_scaled = x2d_scaled.reshape((n_clips, n_time, n_freq))
        x4d_scaled[:,:,:,channel] = x3d_scaled

    if verbose == 1:
        print("Scaling time: %s" % (time.time() - t1,))

    return x4d_scaled

# %%
# earlystopping ends training when the validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
callbacks = [early_stopping]
batch_size = 40
epochs = 150
acc_list = []

for test_fold in range(1, 11):
    print('opening fold:', str(test_fold))

    keras.backend.clear_session()
    model = build_model()

    # compile the model
    model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.001, momentum=0.9, nesterov=True), metrics=['accuracy'])
    train_x, train_y, valid_x, valid_y, test_x, test_y = load_all_folds(test_fold)

    # for each channel, compute scaling factor
    scaler_list = []
    (n_clips, n_time, n_freq, n_channel) = train_x.shape

    for channel in range(n_channel):
        t1 = time.time()
        xtrain_2d = train_x[:, :, :, channel].reshape((n_clips * n_time, n_freq))
        scaler = sklearn.preprocessing.StandardScaler().fit(xtrain_2d)
        # print("Channel %d Mean: %s" % (channel, scaler.mean_,))
        # print("Channel %d Std: %s" % (channel, scaler.scale_,))
        # print("Calculating scaler time: %s" % (time.time() - t1,))
        scaler_list += [scaler]

    train_x = do_scale(train_x)
    valid_x = do_scale(valid_x)
    test_x = do_scale(test_x)
    
    datagen = ImageDataGenerator(
    featurewise_center=True,  # set input mean to 0 over the dataset
    featurewise_std_normalization=True,  # divide inputs by std of the dataset
    rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.4,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    )
    mixupgen = MixupGenerator(train_x, train_y, alpha=1.0, batch_size=batch_size, datagen=datagen)
    test_datagen = ImageDataGenerator(
    featurewise_center=True,  # set input mean to 0 over the dataset
    featurewise_std_normalization=True,  # divide inputs by std of the dataset
    )
    # Compute quantities required for feature-wise normaalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(np.r_[train_x, valid_x, test_x])
    test_datagen.mean, test_datagen.std = datagen.mean, datagen.std
    
    # use a batch size to fully utilize GPU power
    t1 = time.time()
    print("training model...hold tight")
    history = model.fit_generator(mixupgen(),
                    steps_per_epoch=train_x.shape[0] // batch_size,
                    epochs=epochs,
                    validation_data=test_datagen.flow(valid_x, valid_y), validation_steps =len(valid_x) / batch_size, 
                                                      callbacks=callbacks)
    
    print("training time: %s" % (time.time() - t1,))
    
    t2 = time.time()
    acc = evaluate(model, test_x, test_y)
    print("training time: %s" % (time.time() - t2,))

    acc_list += [acc]
# Out:
# opening fold: 1
# Adding  fold2 New Features:  (887, 101, 60, 3)
# Adding  fold3 New Features:  (925, 101, 60, 3)
# Adding  fold4 New Features:  (990, 101, 60, 3)
# Adding  fold5 New Features:  (936, 101, 60, 3)
# Adding  fold6 New Features:  (823, 101, 60, 3)
# Adding  fold7 New Features:  (838, 101, 60, 3)
# Adding  fold8 New Features:  (806, 101, 60, 3)
# Adding  fold9 New Features:  (816, 101, 60, 3)
# Scaling time: 1.8648786544799805
# Scaling time: 0.23363828659057617
# Scaling time: 0.2766416072845459
# training model...hold tight
# Epoch 1/150
# 175/175 [==============================] - 26s - loss: 2.1594 - acc: 0.2877 - val_loss: 1.7254 - val_acc: 0.4062
# Epoch 2/150
# 175/175 [==============================] - 17s - loss: 1.8747 - acc: 0.3439 - val_loss: 1.6452 - val_acc: 0.3661
# Epoch 3/150
# 175/175 [==============================] - 18s - loss: 1.8252 - acc: 0.3800 - val_loss: 1.6063 - val_acc: 0.3395
# Epoch 4/150
# 175/175 [==============================] - 17s - loss: 1.7901 - acc: 0.3976 - val_loss: 1.5671 - val_acc: 0.3271
# Epoch 5/150
# 175/175 [==============================] - 18s - loss: 1.7619 - acc: 0.4253 - val_loss: 1.4625 - val_acc: 0.3891
# Epoch 6/150
# 175/175 [==============================] - 18s - loss: 1.7431 - acc: 0.4350 - val_loss: 1.5596 - val_acc: 0.3659
# Epoch 7/150
# 175/175 [==============================] - 18s - loss: 1.7277 - acc: 0.4377 - val_loss: 1.4826 - val_acc: 0.3891
# Epoch 8/150
# 175/175 [==============================] - 18s - loss: 1.7124 - acc: 0.4469 - val_loss: 1.6315 - val_acc: 0.3795
# Epoch 9/150
# 175/175 [==============================] - 18s - loss: 1.6965 - acc: 0.4611 - val_loss: 1.5706 - val_acc: 0.3482
# Epoch 10/150
# 175/175 [==============================] - 18s - loss: 1.6944 - acc: 0.4599 - val_loss: 1.4549 - val_acc: 0.4388
# Epoch 11/150
# 175/175 [==============================] - 18s - loss: 1.6740 - acc: 0.4641 - val_loss: 1.4470 - val_acc: 0.4016
# Epoch 12/150
# 175/175 [==============================] - 18s - loss: 1.6431 - acc: 0.4799 - val_loss: 1.4878 - val_acc: 0.4016
# Epoch 13/150
# 175/175 [==============================] - 18s - loss: 1.6336 - acc: 0.4896 - val_loss: 1.4382 - val_acc: 0.4109
# Epoch 14/150
# 175/175 [==============================] - 18s - loss: 1.6291 - acc: 0.4991 - val_loss: 1.5135 - val_acc: 0.4078
# Epoch 15/150
# 175/175 [==============================] - 18s - loss: 1.6123 - acc: 0.5040 - val_loss: 1.5038 - val_acc: 0.4226
# Epoch 16/150
# 175/175 [==============================] - 18s - loss: 1.6038 - acc: 0.5064 - val_loss: 1.4838 - val_acc: 0.4171
# Epoch 17/150
# 175/175 [==============================] - 18s - loss: 1.5894 - acc: 0.5279 - val_loss: 1.4369 - val_acc: 0.4233
# Epoch 18/150
# 175/175 [==============================] - 18s - loss: 1.5940 - acc: 0.5280 - val_loss: 1.4226 - val_acc: 0.4295
# Epoch 63/150
# 177/177 [==============================] - 18s - loss: 1.3177 - acc: 0.6761 - val_loss: 1.2549 - val_acc: 0.5685
# Epoch 64/150
# 177/177 [==============================] - 18s - loss: 1.3092 - acc: 0.6831 - val_loss: 1.2641 - val_acc: 0.5364
# Epoch 65/150
# 177/177 [==============================] - 18s - loss: 1.3140 - acc: 0.6852 - val_loss: 1.2074 - val_acc: 0.5411
# Epoch 66/150
# 177/177 [==============================] - 18s - loss: 1.2953 - acc: 0.6953 - val_loss: 1.3033 - val_acc: 0.5147
# Epoch 67/150
# 177/177 [==============================] - 18s - loss: 1.2908 - acc: 0.6886 - val_loss: 1.2135 - val_acc: 0.6264
# Epoch 68/150
# 177/177 [==============================] - 18s - loss: 1.2967 - acc: 0.6910 - val_loss: 1.2214 - val_acc: 0.5891
# Epoch 69/150
# 177/177 [==============================] - 18s - loss: 1.2850 - acc: 0.6924 - val_loss: 1.2236 - val_acc: 0.5238
# Epoch 70/150
# 177/177 [==============================] - 18s - loss: 1.2836 - acc: 0.6884 - val_loss: 1.2058 - val_acc: 0.6295
# Epoch 71/150
# 177/177 [==============================] - 18s - loss: 1.2900 - acc: 0.6996 - val_loss: 1.2304 - val_acc: 0.6016
# Epoch 72/150
# 177/177 [==============================] - 18s - loss: 1.2831 - acc: 0.6966 - val_loss: 1.2059 - val_acc: 0.6093
# Epoch 00071: early stopping
# training time: 1331.8088657855988
# 896/925 [============================>.] - ETA: 0s
# Accuracy = 0.5730
#
# Error Rate = 0.4270
# training time: 1.345170497894287
# opening fold: 4
# Adding  fold1 New Features:  (995, 101, 60, 3)
# Adding  fold2 New Features:  (887, 101, 60, 3)
# Adding  fold3 New Features:  (925, 101, 60, 3)
# Adding  fold5 New Features:  (936, 101, 60, 3)
# Adding  fold6 New Features:  (823, 101, 60, 3)
# Adding  fold7 New Features:  (838, 101, 60, 3)
# Adding  fold8 New Features:  (806, 101, 60, 3)
# Adding  fold9 New Features:  (816, 101, 60, 3)
# Scaling time: 1.8607361316680908
# Scaling time: 0.23174810409545898
# Scaling time: 0.2747690677642822
# training model...hold tight
# Epoch 1/150
# 175/175 [==============================] - 22s - loss: 2.1471 - acc: 0.2931 - val_loss: 1.6535 - val_acc: 0.3973
# Epoch 2/150
# 175/175 [==============================] - 17s - loss: 1.8680 - acc: 0.3534 - val_loss: 1.6328 - val_acc: 0.343812s - loss: 1. - ETA: 11s - loss - ETA: 10s - l
# Epoch 3/150
# 175/175 [==============================] - 18s - loss: 1.8157 - acc: 0.3854 - val_loss: 1.6499 - val_acc: 0.3333
# Epoch 4/150
# 175/175 [==============================] - 18s - loss: 1.7738 - acc: 0.4156 - val_loss: 1.5178 - val_acc: 0.4822
# Epoch 5/150
# 175/175 [==============================] - 17s - loss: 1.7486 - acc: 0.4269 - val_loss: 1.5669 - val_acc: 0.4605
# Epoch 6/150
# 175/175 [==============================] - 18s - loss: 1.7213 - acc: 0.4320 - val_loss: 1.5384 - val_acc: 0.4000
# Epoch 7/150
# Epoch 143/150
# 180/180 [==============================] - 18s - loss: 1.1203 - acc: 0.7704 - val_loss: 0.9256 - val_acc: 0.7012
# Epoch 144/150
# 180/180 [==============================] - 18s - loss: 1.1192 - acc: 0.7764 - val_loss: 1.0133 - val_acc: 0.6738
# Epoch 145/150
# 180/180 [==============================] - 18s - loss: 1.1240 - acc: 0.7692 - val_loss: 0.9372 - val_acc: 0.7256
# Epoch 146/150
# 180/180 [==============================] - 18s - loss: 1.1143 - acc: 0.7772 - val_loss: 0.9891 - val_acc: 0.7073
# Epoch 147/150
# 180/180 [==============================] - 18s - loss: 1.1160 - acc: 0.7776 - val_loss: 0.9770 - val_acc: 0.7039
# Epoch 148/150
# 180/180 [==============================] - 18s - loss: 1.1239 - acc: 0.7771 - val_loss: 0.9974 - val_acc: 0.6433
# Epoch 149/150
# 180/180 [==============================] - 18s - loss: 1.1209 - acc: 0.7821 - val_loss: 1.0864 - val_acc: 0.6677
# Epoch 150/150
# 180/180 [==============================] - 18s - loss: 1.1141 - acc: 0.7832 - val_loss: 1.0251 - val_acc: 0.6601
# training time: 2811.7321553230286
# 800/837 [===========================>..] - ETA: 0s
# Accuracy = 0.6834
#
# Error Rate = 0.3166
# training time: 1.1693589687347412

# %%
acc_array = np.array(acc_list)
print("acc mean %.4f acc std %.4f" % (acc_array.mean(), acc_array.std()))
# Out:
# acc mean 0.6403 acc std 0.0387

# %%
fig = plt.figure(figsize=(16,8))

print("History keys:", (history.history.keys()))
# summarise history for training and validation set accuracy
plt.subplot(1,2,1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# summarise history for training and validation set loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss', fontsize = 'large')
plt.xlabel('epoch', fontsize = 'large' )
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# History keys: dict_keys(['loss', 'val_acc', 'acc', 'val_loss'])

# %%
% matplotlib inline
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix

#model.fit(train_x, train_y, validation_data=(valid_x, valid_y), callbacks=[earlystop], batch_size=32, nb_epoch=50)
acc = evaluate(model, test_x, test_y)  #evaluate(model)

labels = ["air conditioner", "horn", "children", "dog", "drill", "engine", "gun", "hammer", "siren", "music"]
print("Showing Confusion Matrix")
y_prob = model.predict(test_x, verbose=0)
y_pred = np.argmax(y_prob, axis=-1)
y_true = np.argmax(test_y, 1)
cm = confusion_matrix(y_true, y_pred)

def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """pretty print for confusion matrixes"""
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=' ')
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=' ')
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=' ')
        for j in range(len(labels)):
            cell = "%{0}s".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=' ')
        print()

print_cm(cm, labels)

df_cm = pd.DataFrame(cm, labels, labels)
plt.figure(figsize=(16, 8))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 14}, fmt='g', linewidths=.5)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# 800/837 [===========================>..] - ETA: 0s
# Accuracy = 0.6834
#
# Error Rate = 0.3166
# Showing Confusion Matrix
#                     air conditioner            horn        children             dog           drill          engine             gun          hammer           siren           music
#     air conditioner              78               1               4               1               0               4               0               9               1               2
#                horn               0              21               0               0               1               0               0               1               1               9
#            children               0               0              78               4               4               0               0               0               2              12
#                 dog               1               4              17              58               3               1               0               5               2               9
#               drill               5               1               7               1              56               3               0              21               0               6
#              engine               8               0               0               1               1              58               0              13               2              10
#                 gun               0               0               0               3               0               0              29               0               0               0
#              hammer               3               3               0               2               7               4               0              75               0               2
#               siren               8               0              25              10               3               0               0               1              35               1
#               music               1               0               3               0               5               0               0               1               6              84
